# %%
print(type(5))
# Out:
# <class 'int'>

# %%
a="10"
b="20"
print(a+b)
# Out:
# 1020

# %%
a="Ayush"
print(a)
# Out:
# Ayush

# %%
# for comment any line  of code use hashtag
''' use for comment more line'''
# Out:
# ' use for comment more line'

# %%
name="RAm"
marks=70
Grade="A"
'''print(name)
print(marks)'''
print(Grade)
# Out:
# A

# %%
a=4
b=2
print(a+b)
print(a-b)
print(a/b)
print(a%b)
print(a*b)
print(a**b)
print(a//b)
# Out:
# 6
# 2
# 2.0
# 0
# 8
# 16
# 2

# %%
age=20
if age>=18:
    print("Eligible")
# Out:
# Eligible
