# %%
print(type(5))
# Out:
# <class 'int'>

# %%
name="Ayush"
marks=90
grade="A"
print(name)
print(marks)
print(grade)
# Out:
# Ayush
# 90
# A

# %%
a=5
b=7
print(a+b)
# Out:
# 12

# %%
# use for comment single line of code

# %%
'''use for comment more line of code'''

print("hello")
# Out:
# hello

# %%
print(type("Ayush"))
# Out:
# <class 'str'>
