# %%
a=["Quad","AI"]
print(a)
print(type (a))
# Out:
# ['Quad', 'AI']
# <class 'list'>

# %%
print(a)
# Out:
# ['Quad', 'AI']

# %%
b= list(("a" , "b"))
print(b)
# Out:
# ['a', 'b']

# %%
a=[10,20,30,40,50]
print(a[0])
print(a[1])
# Out:
# 10
# 20

# %%
c=[10,20,30,40,50]
print(c)
print(c[0:2])
# Out:
# [10, 20, 30, 40, 50]
# [10, 20]

# %%
c=[10,20,30,40,50]
print(c[1:4])
# Out:
# [20, 30, 40]

# %%
c=[10,20,30,40,50]
print(c[3:])
# Out:
# [40, 50]

# %%
d=[1,2,3,4]
print("before Append",d)
d.append("five")
print("After Append",d)
# Out:
# before Append [1, 2, 3, 4]
# After Append [1, 2, 3, 4, 'five']

# %%
e=[1,2,3,4]
print("before extend", d)
e.extend(["five","six", "true" , 5])
print("after extend", e)
# Out:
# before extend [10, 20, 30, 40, 50]
# after extend [1, 2, 3, 4, 'five', 'six', 'true', 5]

# %%
f=["java","python","js","html"]
print(f)
# Out:
# ['java', 'python', 'js', 'html']

# %%
f.insert(0,"ml")

# %%
f
# Out:
# ['ml', 'java', 'python', 'js', 'html']
